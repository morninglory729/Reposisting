# %% [markdown]
# <a href="https://colab.research.google.com/github/morninglory729/Reposisting/blob/master/ShiftNet_Pills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
torch.__version__
# Out:
# '1.9.0+cu102'

# %%
pip install visdom
# Out:
# ...
#      |████████████████████████████████| 676 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.4 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=6aeeb23f66e667192446b4d10306217a824f8dbf0e3316cb4a0fd955a53a6a38
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5710 sha256=d1cdbccb609e1cfad4b693608aaa177e38602ee1cd238eb0d17096ec00bfa0d3
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built visdom torchfile
# ...

# %%
pip install dominate

# %%
pip install scipy==1.1.0
# Out:
# ...
#      |████████████████████████████████| 31.2 MB 55 kB/s
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc3 3.11.2 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# plotnine 0.6.0 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
cd drive/MyDrive/Shift-Net_pytorch-master/
# Out:
# /content/drive/MyDrive/Shift-Net_pytorch-master

# %%
# !python train.py --offline_loading_mask 1 --batchSize 2 --name ERICA_test --save_epoch_freq 50 --niter 100 --no_flip --dataroot ./datasets/Pills/train/
# Out:
# ----------------- Options ---------------
#            add_mask2input: 1
#                 batchSize: 2                             	[default: 1]
#                     beta1: 0.5
#                bottleneck: 512
#           checkpoints_dir: ./log
#                 constrain: MSE
#            content_weight: 1.0
#            continue_train: False
#                  dataroot: ./datasets/Pills/train/       	[default: ./datasets/Pills/test]
#              dataset_mode: aligned
#               discounting: 1
#               display_env: main
#              display_freq: 100
#                display_id: 1
#             display_ncols: 5
#              display_port: 8097
#            display_server: http://localhost
# display_single_pane_ncols: 0
#           display_winsize: 256
#               epoch_count: 1
#                  fineSize: 256
#                      fuse: 0
#                  gan_type: vanilla
#                gan_weight: 0.2
#                 gp_lambda: 10.0
# ...

# %%
# !python test.py --offline_loading_mask 1 --loadSize 256 --name pills_256 --which_epoch latest --dataroot ./datasets/Pills/test/ --name pills_256_c --no_flip
# Out:
# ----------------- Options ---------------
#            add_mask2input: 1
#              aspect_ratio: 1.0
#                 batchSize: 1
#                bottleneck: 512
#           checkpoints_dir: ./log
#                 constrain: MSE
#            content_weight: 1.0
#                  dataroot: ./datasets/Pills/test/        	[default: ./datasets/Pills/test]
#              dataset_mode: aligned
#               discounting: 1
#           display_winsize: 256
#                  fineSize: 256
#                      fuse: 0
#                  gan_type: vanilla
#                gan_weight: 0.2
#                 gp_lambda: 10.0
#                   gpu_ids: 0
#                  how_many: 1000
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                  lambda_A: 100
#                  loadSize: 256                           	[default: 350]
# ...

# %%
# !python train.py --offline_loading_mask 1 --loadSize 256 --batchSize 1 --name pills_256_a2 --save_epoch_freq 1 --niter 30 --no_flip
